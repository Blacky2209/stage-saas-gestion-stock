# %%
import { useState } from 'react';

function Compteur() {
  // count = valeur actuelle, setCount = fonction pour modifier
  const [count, setCount] = useState(0);

  return (
    <button onClick={() => setCount(count + 1)}>
      Cliquez-moi : {count}
    </button>
  );
}
# Out:
#   Cell In[2], line 1
#     import { useState } from 'react';
#            ^
# SyntaxError: invalid syntax
